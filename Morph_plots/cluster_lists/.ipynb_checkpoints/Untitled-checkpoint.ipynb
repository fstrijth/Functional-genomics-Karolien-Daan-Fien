# %%
install.packages("gridExtra")   # Install & load gridExtra
library("gridExtra")
library("ggplot")
# Out:
# package 'gridExtra' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Hello\AppData\Local\Temp\Rtmp4Ssw5e\downloaded_packages

# %%
library("ggplot2")

# %%
# Load the adjusted p-values of the clinical variables.
age_clusters = read.csv("lowest_padj_AGE.csv")
bmi_clusters = read.csv("lowest_padj_BMI.csv")
height_clusters = read.csv("lowest_padj_HGHT.csv")
weight_clusters = read.csv("lowest_padj_WGHT.csv")

# Load the adjusted p-values of the technical variables.
cohort_clusters = read.csv("lowest_padj_COHORT.csv")
hardy_clusters = read.csv("lowest_padj_DTHHRDY.csv")
ischemic_clusters = read.csv("lowest_padj_TRISCHD.csv")

# %%
cluster_table = data.frame(
    X = c(1:64))

# %%
merged_table = merge(cluster_table, age_clusters[, c("X", "padj")], by = "X", all.x = TRUE)
colnames(merged_table)[colnames(merged_table) == "padj"] <- "Age"

merged_table2 = merge(merged_table, bmi_clusters[, c("X", "padj")], by = "X", all.x = TRUE)
colnames(merged_table2)[colnames(merged_table2) == "padj"] <- "BMI"

merged_table3 = merge(merged_table2, height_clusters[, c("X", "padj")], by = "X", all.x = TRUE)
colnames(merged_table3)[colnames(merged_table3) == "padj"] <- "Height"

merged_table4 = merge(merged_table3, weight_clusters[, c("X", "padj")], by = "X", all.x = TRUE)
colnames(merged_table4)[colnames(merged_table4) == "padj"] <- "Weight"

merged_table5 = merge(merged_table4, ischemic_clusters[, c("X", "padj")], by = "X", all.x = TRUE)
colnames(merged_table5)[colnames(merged_table5) == "padj"] <- "Ischemic time"

merged_table6 = merge(merged_table5, cohort_clusters[, c("X", "padj")], by = "X", all.x = TRUE)
colnames(merged_table6)[colnames(merged_table6) == "padj"] <- "Donor type"

final_table = merge(merged_table6, hardy_clusters[, c("X", "padj")], by = "X", all.x = TRUE)
colnames(final_table)[colnames(final_table) == "padj"] <- "Hardy scale"


final_table = final_table[, -which(names(final_merged_table) == "X")]

# %%
final_table <- replace(final_table, is.na(final_table), "")

# %%
final_xtable <- xtable(final_table)

# %%
latex_code <- print.xtable(final_xtable,tabular.environment = "longtable", floating = FALSE)

cat(latex_code)
# Out:
# % latex table generated in R 4.1.3 by xtable 1.8-4 package
# % Fri May 26 17:54:36 2023
# \begin{longtable}{rlllllll}
#   \hline
#  & Age & BMI & Height & Weight & Ischemic.time & Donor.type & Hardy.scale \\
#   \hline
# 1 &  &  & 0.0172269068254905 &  & 5.54566954369357e-10 & 1.790400685578e-05 & 0.00340626281202144 \\
#   2 & 0.00119763730683171 &  &  &  & 0.000256725967950822 & 0.000153711244505758 &  \\
#   3 & 0.0514929775297685 &  & 0.0387172076870965 &  & 0.00283024264876568 & 0.00854147401344125 & 0.0600309149346212 \\
#   4 & 0.0106435305202789 & 0.030170785414246 & 0.00223962685184363 & 0.000375164878768905 & 1.55096873342158e-10 & 7.26020562111479e-15 & 0.0455168701185212 \\
#   5 &  &  & 0.0654794797116721 &  & 0.000757497730150143 & 6.73595949821384e-18 & 2.16979659419499e-06 \\
#   6 & 0.00109598439420994 &  &  &  & 0.00546915054246236 & 9.41776208379053e-07 & 0.0345526397047787 \\
#   7 &  &  &  &  & 0.0386437986938298 & 0.0764346936812948 &  \\
#   8 & 0.0988777650964691 &  & 0.00839313947481864 & 0.0171817165463516 & 0.0962137156587231 & 0.0937874375731565 &  \\
#   9 & 0.000158377470427845 & 0.0523175349153954 &  &  & 4.10150456690288e-05 & 0.0276779863899125 &  \\
#   10 & 0.0206068368542866 &  &  &  &  &  &  \\
#   11 & 0.00109598439420994 &  &  &  & 0.00768279630536384 & 0.0130296599197817 &  \\
#   12 & 0.00837262150308055 &  & 0.000368577342925815 & 0.000375164878768905 & 8.52016967493668e-18 & 4.25702640221165e-20 & 0.00582602436062374 \\
#   13 & 0.000803802773294144 &  & 0.0176092226563741 & 0.0574365072934033 &  &  &  \\
#   14 &  &  &  &  & 0.0301391745652722 &  &  \\
#   15 &  & 0.0142592330840835 & 0.00614319449549272 & 0.000345121382605952 & 0.000431624761472049 & 8.99261808241249e-05 &  \\
#   16 & 0.0016694974581431 &  &  &  & 0.00283024264876568 & 5.53755044863085e-07 & 0.00076510840753503 \\
#   17 &  &  &  &  & 0.0626696760878234 & 0.0164324519647044 & 0.032702615358354 \\
#   18 &  & 0.044321690650618 &  & 0.0143156539265841 &  & 0.0223801005496911 &  \\
#   19 & 0.000578841640474228 &  &  & 0.0515504380434369 &  &  &  \\
#   20 &  &  & 0.00545697981318232 & 0.0726213434980392 & 8.74808903375638e-06 & 0.00100665630800323 &  \\
#   21 &  &  &  &  & 0.0407095708925897 & 0.0378072791316105 &  \\
#   22 & 0.0415845935578501 &  & 0.0197549874973563 & 0.00843095751359967 &  &  &  \\
#   23 &  &  & 0.0453707580002699 & 0.0574739570872906 & 7.07858877451154e-05 & 5.54709820131595e-09 & 0.0345526397047787 \\
#   24 &  &  &  &  &  &  & 0.0710444137016707 \\
#   25 & 0.00109598439420994 &  &  &  & 0.000753975987919586 & 0.0028468023666257 & 0.0710444137016707 \\
#   26 &  & 0.030170785414246 & 0.00880505252171091 & 0.000116802397877115 & 1.26203655436305e-22 & 6.21036998331493e-13 & 0.000136986123848756 \\
#   27 & 0.000204410938729314 &  & 0.0444201212785517 &  &  &  &  \\
#   28 & 0.0025993701473478 &  &  &  & 0.0245362073924437 & 3.79020904636256e-10 & 1.97544307803178e-08 \\
#   29 & 9.31398212939945e-05 &  &  &  & 7.06255698346245e-05 & 0.000190073116104168 &  \\
#   30 & 0.0106435305202789 & 0.0844813964828957 &  & 0.0612208544777149 &  &  & 0.0354633280792196 \\
#   31 & 0.00782642361983614 &  & 0.014470501490129 & 0.0244185492955686 & 0.00768279630536384 & 0.00438771926254125 &  \\
#   32 &  &  & 0.0169244433263194 & 0.0176164514237154 & 3.07224017489154e-06 & 3.00976284786681e-06 & 0.0163348207175184 \\
#   33 & 0.00144131876233447 &  &  & 0.0194431846188691 & 4.01920607355589e-31 & 6.28231496992853e-23 & 1.73612752669747e-06 \\
#   34 & 0.00639823925129696 &  & 0.00223962685184363 & 0.0436971659954648 & 2.10536660912079e-06 & 6.61439045771095e-09 & 0.0268224719220661 \\
#   35 &  &  &  &  & 0.000753975987919586 & 5.00416551528731e-20 & 1.97544307803178e-08 \\
#   36 &  &  &  & 0.0436971659954648 &  &  & 0.0895533579294224 \\
#   37 & 0.00162315888459423 &  & 0.0169244433263194 & 0.0436971659954648 &  &  &  \\
#   38 & 0.0102624983406287 &  & 0.00395053305721776 & 0.0189443096832821 & 0.092578889596349 &  &  \\
#   39 &  &  & 0.000245448848286006 & 0.0442257694192887 & 4.85441641931314e-28 & 7.34212889970871e-14 & 5.33315824617362e-05 \\
#   40 & 3.58672806500445e-06 &  &  &  & 0.00818769417806873 & 0.00343909772427892 &  \\
#   41 & 0.00269708771853255 & 0.00745859552558766 & 0.0387172076870965 & 0.000375232173463825 &  &  &  \\
#   42 &  &  & 0.0169244433263194 & 0.00203124927083149 &  & 0.010714484465931 &  \\
#   43 &  &  &  &  & 0.000534397625661706 & 0.0339990202584642 &  \\
#   44 & 2.01406509697294e-06 &  &  &  & 0.00546915054246236 & 0.00174308543954852 &  \\
#   45 &  &  &  &  &  &  & 0.0197728691343823 \\
#   46 &  & 0.0969660158851345 & 0.0041833941666295 & 0.00203124927083149 & 6.32123803221804e-09 & 1.23531483711049e-14 & 0.0399220277104912 \\
#   47 &  &  &  &  &  &  & 0.00340626281202144 \\
#   48 & 0.000158377470427845 &  & 0.0444201212785517 & 0.0574739570872906 & 1.21537469382147e-17 & 2.00821593953428e-21 & 0.000136986123848756 \\
#   49 &  & 0.0478069906952831 &  & 0.014946651017045 & 0.0563150835983833 & 0.0164324519647044 &  \\
#   50 & 4.69537272134703e-06 &  &  &  & 0.0595299682028863 & 0.00284791310742687 & 0.0673946195700387 \\
#   51 &  &  &  &  & 5.87471207056404e-11 & 2.31363127255223e-11 & 9.09091452098546e-05 \\
#   52 &  & 0.00084237438159674 &  & 0.000375164878768905 & 0.00030010239616674 & 0.00063610892701092 &  \\
#   53 & 1.05345167848481e-05 &  &  &  &  & 0.00531839798990676 & 0.0259294917925963 \\
#   54 &  &  & 0.00502269730400481 &  &  & 1.80977653097078e-05 & 0.00212912447509339 \\
#   55 &  &  &  &  &  & 0.0621507115574942 & 0.0494630510035482 \\
#   56 & 0.00782642361983614 &  &  &  & 2.10536660912079e-06 & 5.18916530130634e-06 & 0.0399220277104912 \\
#   57 &  &  & 0.00547216376987776 & 0.0134140704299518 & 1.13604911224096e-24 & 3.44589203798278e-25 & 6.82862961559152e-06 \\
#   58 & 0.0158259968915816 &  &  &  &  & 6.98564618954084e-05 &  \\
#   59 &  & 0.0478069906952831 &  & 0.00843095751359967 &  & 0.0937874375731565 &  \\
#   60 & 0.0592026587100454 &  &  &  & 2.48186353866789e-08 & 2.38990141673868e-08 & 0.00914201964371096 \\
#   61 &  &  &  &  & 4.51867946124751e-12 & 8.07871065228402e-10 & 0.00303359045967303 \\
#   62 & 4.64155396347065e-05 &  &  &  & 0.00283024264876568 & 0.00243285382985213 &  \\
#   63 &  &  & 0.00502269730400481 &  & 2.73750790350878e-14 & 6.9107305246092e-06 & 0.00264198550621791 \\
#   64 &  &  &  &  &  &  &  \\
#    \hline
# \hline
# \end{longtable}
# % latex table generated in R 4.1.3 by xtable 1.8-4 package
# % Fri May 26 17:54:36 2023
# \begin{longtable}{rlllllll}
#   \hline
#  & Age & BMI & Height & Weight & Ischemic.time & Donor.type & Hardy.scale \\
#   \hline
# 1 &  &  & 0.0172269068254905 &  & 5.54566954369357e-10 & 1.790400685578e-05 & 0.00340626281202144 \\
#   2 & 0.00119763730683171 &  &  &  & 0.000256725967950822 & 0.000153711244505758 &  \\
#   3 & 0.0514929775297685 &  & 0.0387172076870965 &  & 0.00283024264876568 & 0.00854147401344125 & 0.0600309149346212 \\
#   4 & 0.0106435305202789 & 0.030170785414246 & 0.00223962685184363 & 0.000375164878768905 & 1.55096873342158e-10 & 7.26020562111479e-15 & 0.0455168701185212 \\
#   5 &  &  & 0.0654794797116721 &  & 0.000757497730150143 & 6.73595949821384e-18 & 2.16979659419499e-06 \\
#   6 & 0.00109598439420994 &  &  &  & 0.00546915054246236 & 9.41776208379053e-07 & 0.0345526397047787 \\
#   7 &  &  &  &  & 0.0386437986938298 & 0.0764346936812948 &  \\
#   8 & 0.0988777650964691 &  & 0.00839313947481864 & 0.0171817165463516 & 0.0962137156587231 & 0.0937874375731565 &  \\
#   9 & 0.000158377470427845 & 0.0523175349153954 &  &  & 4.10150456690288e-05 & 0.0276779863899125 &  \\
#   10 & 0.0206068368542866 &  &  &  &  &  &  \\
#   11 & 0.00109598439420994 &  &  &  & 0.00768279630536384 & 0.0130296599197817 &  \\
#   12 & 0.00837262150308055 &  & 0.000368577342925815 & 0.000375164878768905 & 8.52016967493668e-18 & 4.25702640221165e-20 & 0.00582602436062374 \\
#   13 & 0.000803802773294144 &  & 0.0176092226563741 & 0.0574365072934033 &  &  &  \\
#   14 &  &  &  &  & 0.0301391745652722 &  &  \\
#   15 &  & 0.0142592330840835 & 0.00614319449549272 & 0.000345121382605952 & 0.000431624761472049 & 8.99261808241249e-05 &  \\
#   16 & 0.0016694974581431 &  &  &  & 0.00283024264876568 & 5.53755044863085e-07 & 0.00076510840753503 \\
#   17 &  &  &  &  & 0.0626696760878234 & 0.0164324519647044 & 0.032702615358354 \\
#   18 &  & 0.044321690650618 &  & 0.0143156539265841 &  & 0.0223801005496911 &  \\
#   19 & 0.000578841640474228 &  &  & 0.0515504380434369 &  &  &  \\
#   20 &  &  & 0.00545697981318232 & 0.0726213434980392 & 8.74808903375638e-06 & 0.00100665630800323 &  \\
#   21 &  &  &  &  & 0.0407095708925897 & 0.0378072791316105 &  \\
#   22 & 0.0415845935578501 &  & 0.0197549874973563 & 0.00843095751359967 &  &  &  \\
#   23 &  &  & 0.0453707580002699 & 0.0574739570872906 & 7.07858877451154e-05 & 5.54709820131595e-09 & 0.0345526397047787 \\
#   24 &  &  &  &  &  &  & 0.0710444137016707 \\
#   25 & 0.00109598439420994 &  &  &  & 0.000753975987919586 & 0.0028468023666257 & 0.0710444137016707 \\
#   26 &  & 0.030170785414246 & 0.00880505252171091 & 0.000116802397877115 & 1.26203655436305e-22 & 6.21036998331493e-13 & 0.000136986123848756 \\
#   27 & 0.000204410938729314 &  & 0.0444201212785517 &  &  &  &  \\
#   28 & 0.0025993701473478 &  &  &  & 0.0245362073924437 & 3.79020904636256e-10 & 1.97544307803178e-08 \\
#   29 & 9.31398212939945e-05 &  &  &  & 7.06255698346245e-05 & 0.000190073116104168 &  \\
#   30 & 0.0106435305202789 & 0.0844813964828957 &  & 0.0612208544777149 &  &  & 0.0354633280792196 \\
#   31 & 0.00782642361983614 &  & 0.014470501490129 & 0.0244185492955686 & 0.00768279630536384 & 0.00438771926254125 &  \\
#   32 &  &  & 0.0169244433263194 & 0.0176164514237154 & 3.07224017489154e-06 & 3.00976284786681e-06 & 0.0163348207175184 \\
#   33 & 0.00144131876233447 &  &  & 0.0194431846188691 & 4.01920607355589e-31 & 6.28231496992853e-23 & 1.73612752669747e-06 \\
#   34 & 0.00639823925129696 &  & 0.00223962685184363 & 0.0436971659954648 & 2.10536660912079e-06 & 6.61439045771095e-09 & 0.0268224719220661 \\
#   35 &  &  &  &  & 0.000753975987919586 & 5.00416551528731e-20 & 1.97544307803178e-08 \\
#   36 &  &  &  & 0.0436971659954648 &  &  & 0.0895533579294224 \\
#   37 & 0.00162315888459423 &  & 0.0169244433263194 & 0.0436971659954648 &  &  &  \\
#   38 & 0.0102624983406287 &  & 0.00395053305721776 & 0.0189443096832821 & 0.092578889596349 &  &  \\
#   39 &  &  & 0.000245448848286006 & 0.0442257694192887 & 4.85441641931314e-28 & 7.34212889970871e-14 & 5.33315824617362e-05 \\
#   40 & 3.58672806500445e-06 &  &  &  & 0.00818769417806873 & 0.00343909772427892 &  \\
#   41 & 0.00269708771853255 & 0.00745859552558766 & 0.0387172076870965 & 0.000375232173463825 &  &  &  \\
#   42 &  &  & 0.0169244433263194 & 0.00203124927083149 &  & 0.010714484465931 &  \\
#   43 &  &  &  &  & 0.000534397625661706 & 0.0339990202584642 &  \\
#   44 & 2.01406509697294e-06 &  &  &  & 0.00546915054246236 & 0.00174308543954852 &  \\
#   45 &  &  &  &  &  &  & 0.0197728691343823 \\
#   46 &  & 0.0969660158851345 & 0.0041833941666295 & 0.00203124927083149 & 6.32123803221804e-09 & 1.23531483711049e-14 & 0.0399220277104912 \\
#   47 &  &  &  &  &  &  & 0.00340626281202144 \\
#   48 & 0.000158377470427845 &  & 0.0444201212785517 & 0.0574739570872906 & 1.21537469382147e-17 & 2.00821593953428e-21 & 0.000136986123848756 \\
#   49 &  & 0.0478069906952831 &  & 0.014946651017045 & 0.0563150835983833 & 0.0164324519647044 &  \\
#   50 & 4.69537272134703e-06 &  &  &  & 0.0595299682028863 & 0.00284791310742687 & 0.0673946195700387 \\
#   51 &  &  &  &  & 5.87471207056404e-11 & 2.31363127255223e-11 & 9.09091452098546e-05 \\
#   52 &  & 0.00084237438159674 &  & 0.000375164878768905 & 0.00030010239616674 & 0.00063610892701092 &  \\
#   53 & 1.05345167848481e-05 &  &  &  &  & 0.00531839798990676 & 0.0259294917925963 \\
#   54 &  &  & 0.00502269730400481 &  &  & 1.80977653097078e-05 & 0.00212912447509339 \\
#   55 &  &  &  &  &  & 0.0621507115574942 & 0.0494630510035482 \\
#   56 & 0.00782642361983614 &  &  &  & 2.10536660912079e-06 & 5.18916530130634e-06 & 0.0399220277104912 \\
#   57 &  &  & 0.00547216376987776 & 0.0134140704299518 & 1.13604911224096e-24 & 3.44589203798278e-25 & 6.82862961559152e-06 \\
#   58 & 0.0158259968915816 &  &  &  &  & 6.98564618954084e-05 &  \\
#   59 &  & 0.0478069906952831 &  & 0.00843095751359967 &  & 0.0937874375731565 &  \\
#   60 & 0.0592026587100454 &  &  &  & 2.48186353866789e-08 & 2.38990141673868e-08 & 0.00914201964371096 \\
#   61 &  &  &  &  & 4.51867946124751e-12 & 8.07871065228402e-10 & 0.00303359045967303 \\
#   62 & 4.64155396347065e-05 &  &  &  & 0.00283024264876568 & 0.00243285382985213 &  \\
#   63 &  &  & 0.00502269730400481 &  & 2.73750790350878e-14 & 6.9107305246092e-06 & 0.00264198550621791 \\
#   64 &  &  &  &  &  &  &  \\
#    \hline
# \hline
# \end{longtable}
